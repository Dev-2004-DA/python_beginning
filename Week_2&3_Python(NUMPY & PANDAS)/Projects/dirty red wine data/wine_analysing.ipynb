# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ANALYSING THE CLEANED DATA

# %%
df=pd.read_csv('redwine_cleaned.csv')

# %% [markdown]
# STRUCTURE OF DATA

# %%
# df=df.drop(['Unnamed: 0'],axis=1)
# print(df.to_string())
print(f"Total number of columns {len(df.columns)} namely:")
for col in df:
    print(col,end=", ")
print()
print(f"Total nnumber of rows {len(df.index)}")
print("First five rows are \n\n",df.head().to_string())
# Out:
# Total number of columns 13 namely:
# Unnamed: 0, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality,
# Total nnumber of rows 1368
# First five rows are
#
#     Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0           0            7.4              0.70         0.00             1.9      0.076                 11.0                  34.0   0.9978  3.51       0.56      9.4        5
# 1           1            7.8              0.88         0.00             2.6      0.098                 25.0                  67.0   0.9968  3.20       0.68      9.8        5
# 2           2            7.8              0.76         0.04             2.3      0.092                 15.0                  54.0   0.9970  3.26       0.65      9.8        5
# ...

# %% [markdown]
# basic staistics for each columns

# %%
y=df.columns                                                # list of columns 
for col in y: 
    print(f"Column--\"{col}\"")
    print(f"Basic Statistics \n{df[col].describe().round(3)}")
    print("Visualization")
    df[col].plot(kind='hist')
    plt.show()
# Out:
# Column--"Unnamed: 0"
# Basic Statistics
# count    1368.000
# mean      683.500
# std       395.052
# min         0.000
# 25%       341.750
# 50%       683.500
# 75%      1025.250
# max      1367.000
# Name: Unnamed: 0, dtype: float64
# Visualization
# Column--"fixed acidity"
# Basic Statistics
# count    1368.000
# mean        8.306
# std         1.733
# min         4.600
# 25%         7.100
# 50%         7.900
# 75%         9.200
# max        15.900
# Name: fixed acidity, dtype: float64
# Visualization
# Column--"volatile acidity"
# Basic Statistics
# count    1368.000
# mean        0.529
# std         0.183
# min         0.120
# 25%         0.390
# 50%         0.520
# 75%         0.640
# max         1.580
# Name: volatile acidity, dtype: float64
# Visualization
# Column--"citric acid"
# Basic Statistics
# count    1368.000
# mean        0.273
# std         0.195
# min         0.000
# 25%         0.100
# 50%         0.260
# 75%         0.430
# max         1.000
# ...

# %%
x=df.corr().round(2).to_string()
print(x)
# Out:
#                       Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  alcohol  quality
# Unnamed: 0                  1.00          -0.26             -0.02        -0.15           -0.02      -0.14                 0.07                 -0.14    -0.37  0.10      -0.12     0.27     0.08
# fixed acidity              -0.26           1.00             -0.25         0.67            0.11       0.09                -0.14                 -0.10     0.67 -0.48       0.19    -0.05     0.12
# volatile acidity           -0.02          -0.25              1.00        -0.55           -0.01       0.05                -0.02                  0.07     0.02  0.20      -0.26    -0.20    -0.39
# citric acid                -0.15           0.67             -0.55         1.00            0.14       0.21                -0.05                  0.05     0.36 -0.40       0.33     0.11     0.23
# ...
